# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs 
from sklearn.cluster import KMeans

# %%
X, y = make_blobs(n_samples=150, n_features=2, centers=4, cluster_std = 6, random_state=1)
plt.scatter(X[:,0], X[:, 1]) 
plt.show()

# %%
kmeans = KMeans(n_clusters=4, n_init=5) 
kmeans.fit(X)
labels = kmeans.labels_
cluster_centers = kmeans.cluster_centers_
plt.scatter(X[:,0], X[:, 1], c=labels)
plt.scatter(cluster_centers [:,0], cluster_centers [:, 1], marker = "*") 
plt.show()
print(cluster_centers) 
print(kmeans.inertia_)
# Out:
# [[ -8.13213383 -10.96994383]
#  [-10.58061405  -0.62805453]
#  [ -1.38995983   7.38123187]
#  [  1.40269291  -5.66734046]]
# 4422.4352524492915
